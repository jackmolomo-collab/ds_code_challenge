# %%
import json
from io import BytesIO

KEY = "city-hex-polygons-8-10.geojson"

response = s3.get_object(
    Bucket=BUCKET,
    Key=KEY
)

hex_8_10_data = json.loads(
    response["Body"].read()
)

print(type(hex_8_10_data))
print(hex_8_10_data.keys())
