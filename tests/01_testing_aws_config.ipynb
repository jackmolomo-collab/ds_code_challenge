# %%
from pathlib import Path
import yaml

config_path = Path(__file__).parent.parent / "config" / "config.yaml"

with open(config_path, "r") as file:
    aws_config = yaml.safe_load(file)

print("✅ AWS configuration loaded successfully")
print(f"Region: {aws_config['aws']['region']}")
print(f"Bucket: {aws_config['s3']['bucket']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 import yaml
#       4 config_path = Path(__file__).parent.parent / "config" / "config.yaml"
#       6 with open(config_path, "r") as file:
#
# ModuleNotFoundError: No module named 'yaml'
