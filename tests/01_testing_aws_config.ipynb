# %%
# %pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import yaml

PROJECT_ROOT = Path.cwd().parent

config_path = PROJECT_ROOT / "config" / "aws.yaml"

print(f"Project root: {PROJECT_ROOT}")
print(f"Config path : {config_path}")
print(f"Exists      : {config_path.exists()}")
# Out:
# Project root: c:\Projects\City of Cape Town\Project\ds_code_challenge
# Config path : c:\Projects\City of Cape Town\Project\ds_code_challenge\config\aws.yaml
# Exists      : True

# %%
import yaml

with open(config_path, "r") as file:
    aws_config = yaml.safe_load(file)

print("AWS configuration loaded successfully")
print(aws_config)
# Out:
# AWS configuration loaded successfully
# {'aws': {'region': 'af-south-1'}, 's3': {'bucket': 'cct-ds-code-challenge-input-data'}}
