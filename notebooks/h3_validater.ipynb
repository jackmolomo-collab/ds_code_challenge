# %%
# %pip install polars
# Out:
# Collecting polars
#   Downloading polars-1.43.2-py3-none-any.whl (847 kB)
# Collecting polars-runtime-32==1.43.2
#   Downloading polars_runtime_32-1.43.2-cp310-abi3-win_amd64.whl (52.6 MB)
# Installing collected packages: polars-runtime-32, polars
# Successfully installed polars-1.43.2 polars-runtime-32-1.43.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.insert(0, "..")
from validation.h3_validator import H3Validator

validator = H3Validator()

result = validator.validate(
    "city-hex-polygons-8-10.geojson"
)

print(result)
# Out:
# {'aws': {'region': 'af-south-1'}, 's3': {'bucket': 'cct-ds-code-challenge-input-data'}}
# {'source': 'city-hex-polygons-8-10.geojson', 'total': 203840, 'valid': 3832, 'invalid': 200008, 'score': 0.01879905808477237, 'passed': False}
