# %% [markdown]
# this is a note book for discovring source data and mini analysis

# %%
# %pip install boto3 pandas
# Out:
# Collecting boto3
#   Downloading boto3-1.43.77-py3-none-any.whl (140 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
# Collecting botocore<1.44.0,>=1.43.77
#   Downloading botocore-1.43.77-py3-none-any.whl (15.7 MB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.20.0,>=0.19.0
#   Downloading s3transfer-0.19.2-py3-none-any.whl (90 kB)
# Collecting numpy>=1.22.4
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2026.3.post1-py2.py3-none-any.whl (508 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting urllib3!=2.2.0,<3,>=1.25.4
#   Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: urllib3, jmespath, botocore, tzdata, s3transfer, pytz, numpy, pandas, boto3
# Successfully installed boto3-1.43.77 botocore-1.43.77 jmespath-1.1.0 numpy-2.2.6 pandas-2.3.3 pytz-2026.3.post1 s3transfer-0.19.2 tzdata-2026.3 urllib3-2.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import pandas as pd

BUCKET = "cct-ds-code-challenge-input-data"
REGION = "af-south-1"

s3 = boto3.client(
    "s3",
    region_name=REGION
)

# %%
response = s3.list_objects_v2(Bucket=BUCKET)

for file in response["Contents"]:
    print(file["Key"])
# Out:
# city-hex-polygons-7.geojson
# city-hex-polygons-8-10.geojson
# city-hex-polygons-8.geojson
# ds_code_challenge_creds.json
# images/swimming-pool/no/W07C_11_100.tif
# images/swimming-pool/no/W07C_11_61.tif
# images/swimming-pool/no/W07C_11_71.tif
# images/swimming-pool/no/W07C_11_82.tif
# images/swimming-pool/no/W07C_11_88.tif
# images/swimming-pool/no/W07C_11_97.tif
# images/swimming-pool/no/W07C_16_1.tif
# images/swimming-pool/no/W07C_16_10.tif
# images/swimming-pool/no/W07C_16_17.tif
# images/swimming-pool/no/W07C_16_24.tif
# images/swimming-pool/no/W07C_16_25.tif
# images/swimming-pool/no/W07C_16_27.tif
# images/swimming-pool/no/W07C_16_29.tif
# images/swimming-pool/no/W07C_16_35.tif
# images/swimming-pool/no/W07C_16_36.tif
# images/swimming-pool/no/W07C_16_38.tif
# images/swimming-pool/no/W07C_16_39.tif
# images/swimming-pool/no/W07C_16_40.tif
# images/swimming-pool/no/W07C_16_45.tif
# images/swimming-pool/no/W07C_16_46.tif
# images/swimming-pool/no/W07C_16_47.tif
# images/swimming-pool/no/W07C_16_5.tif
# images/swimming-pool/no/W07C_16_52.tif
# images/swimming-pool/no/W07C_16_53.tif
# images/swimming-pool/no/W07C_16_6.tif
# images/swimming-pool/no/W07C_16_62.tif
# images/swimming-pool/no/W07C_16_64.tif
# images/swimming-pool/no/W07C_16_67.tif
# images/swimming-pool/no/W07C_16_68.tif
# images/swimming-pool/no/W07C_16_78.tif
# images/swimming-pool/no/W07C_16_82.tif
# images/swimming-pool/no/W17D_20_8.tif
# images/swimming-pool/no/W17D_20_82.tif
# images/swimming-pool/no/W17D_20_83.tif
# images/swimming-pool/no/W17D_20_84.tif
# images/swimming-pool/no/W17D_20_85.tif
# images/swimming-pool/no/W17D_20_9.tif
# images/swimming-pool/no/W17D_20_91.tif
# images/swimming-pool/no/W17D_20_94.tif
# images/swimming-pool/no/W17D_20_96.tif
# images/swimming-pool/no/W17D_21_10.tif
# images/swimming-pool/no/W17D_21_20.tif
# images/swimming-pool/no/W17D_21_29.tif
# images/swimming-pool/no/W17D_21_50.tif
# images/swimming-pool/no/W17D_21_8.tif
# images/swimming-pool/no/W17D_21_9.tif
# images/swimming-pool/no/W17D_22_11.tif
# images/swimming-pool/no/W17D_22_13.tif
# images/swimming-pool/no/W17D_22_3.tif
# images/swimming-pool/no/W17D_22_34.tif
# images/swimming-pool/no/W17D_22_35.tif
# images/swimming-pool/no/W17D_22_4.tif
# images/swimming-pool/no/W17D_22_41.tif
# images/swimming-pool/no/W17D_22_45.tif
# images/swimming-pool/no/W17D_22_46.tif
# images/swimming-pool/no/W17D_22_47.tif
# images/swimming-pool/no/W17D_22_55.tif

# %%
import boto3
import pandas as pd

BUCKET = "cct-ds-code-challenge-input-data"
REGION = "af-south-1"

s3 = boto3.client(
    "s3",
    region_name=REGION
)

response = s3.list_objects_v2(Bucket=BUCKET)

files = []

for obj in response.get("Contents", []):
    files.append({
        "key": obj["Key"],
        "size_bytes": obj["Size"],
        "last_modified": obj["LastModified"]
    })

files_df = pd.DataFrame(files)

files_df
# Out:
#                                          key  size_bytes  \
# 0                city-hex-polygons-7.geojson      276231
# 1             city-hex-polygons-8-10.geojson   108254980
# 2                city-hex-polygons-8.geojson     1966685
# 3               ds_code_challenge_creds.json         115
# 4    images/swimming-pool/no/W07C_11_100.tif     3932696
# ..                                       ...         ...
# 995   images/swimming-pool/no/W17D_22_41.tif     3911391
# 996   images/swimming-pool/no/W17D_22_45.tif     4134574
# 997   images/swimming-pool/no/W17D_22_46.tif     4125109
# 998   images/swimming-pool/no/W17D_22_47.tif     4147367
# 999   images/swimming-pool/no/W17D_22_55.tif     4192969
#
#                 last_modified
# 0   2021-05-14 09:52:18+00:00
# 1   2021-05-14 09:44:09+00:00
# 2   2021-05-14 13:10:00+00:00
# 3   2021-05-14 16:34:40+00:00
# 4   2025-06-12 09:03:22+00:00
# ..                        ...
# 995 2025-06-12 09:03:38+00:00
# 996 2025-06-12 09:03:38+00:00
# 997 2025-06-12 09:03:38+00:00
# 998 2025-06-12 09:03:38+00:00
# 999 2025-06-12 09:03:38+00:00
#
# [1000 rows x 3 columns]

# %%
files_df["file_type"] = (
    files_df["key"]
    .str.lower()
    .str.split(".")
    .str[-1]
)

files_df["file_type"].value_counts()
# Out:
# file_type
# tif        996
# geojson      3
# json         1
# Name: count, dtype: int64

# %%
import json

KEY = "city-hex-polygons-7.geojson"

response = s3.get_object(
    Bucket=BUCKET,
    Key=KEY
)

geojson_data = json.loads(
    response["Body"].read()
)

type(geojson_data)
# Out:
# dict

# %%
geojson_data.keys()
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])

# %%
len(geojson_data["features"])
# Out:
# 627

# %%
geojson_data["features"][0]
# Out:
# {'type': 'Feature',
#  'properties': {'index': '87ad36180ffffff'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[18.69026825870867, -33.86703319751351],
#     [18.69168980931549, -33.85511764511594],
#     [18.679265404549795, -33.84751122474886],
#     [18.66542004486691, -33.8518201940735],
#     [18.663997091762614, -33.86373510896562],
#     [18.676420900551488, -33.87134169227918],
#     [18.69026825870867, -33.86703319751351]]]}}

# %%
features_df = pd.json_normalize(
    geojson_data["features"]
)

features_df.head()
# Out:
#       type properties.index geometry.type  \
# 0  Feature  87ad36180ffffff       Polygon
# 1  Feature  87ad36181ffffff       Polygon
# 2  Feature  87ad36182ffffff       Polygon
# 3  Feature  87ad36183ffffff       Polygon
# 4  Feature  87ad36184ffffff       Polygon
#
#                                 geometry.coordinates
# 0  [[[18.69026825870867, -33.86703319751351], [18...
# 1  [[[18.663997091762614, -33.86373510896562], [1...
# 2  [[[18.705536812042357, -33.850805737933875], [...
# 3  [[[18.679265404549795, -33.84751122474886], [1...
# 4  [[[18.70127401694917, -33.88655041755364], [18...

# %%
# Number of rows and columns
features_df.shape
# Out:
# (627, 4)

# %%
features_df.dtypes
# Out:
# type                    object
# properties.index        object
# geometry.type           object
# geometry.coordinates    object
# dtype: object

# %%
# Check whether the hex IDs are unique
features_df["properties.index"].nunique()
# Out:
# 627

# %% [markdown]
# discovery finding:
#
# Source: city-hex-polygons-7.geojson
# Format: GeoJSON
# Records: 627
# Geometry: Polygon
# Business/geospatial identifier: properties.index
# Unique identifiers: 627 / 627

# %%
features_df.isnull().sum()
# Out:
# type                    0
# properties.index        0
# geometry.type           0
# geometry.coordinates    0
# dtype: int64

# %%
features_df["geometry.type"].value_counts()
# Out:
# geometry.type
# Polygon    627
# Name: count, dtype: int64

# %%
features_df["type"].value_counts()
# Out:
# type
# Feature    627
# Name: count, dtype: int64

# %% [markdown]
# what axctly is in the the 1,000 objects

# %%
files_df["file_type"].value_counts()
# Out:
# file_type
# tif        996
# geojson      3
# json         1
# Name: count, dtype: int64

# %%
files_df[
    files_df["key"].str.startswith("images/")
]["key"].head(20)
# Out:
# 4     images/swimming-pool/no/W07C_11_100.tif
# 5      images/swimming-pool/no/W07C_11_61.tif
# 6      images/swimming-pool/no/W07C_11_71.tif
# 7      images/swimming-pool/no/W07C_11_82.tif
# 8      images/swimming-pool/no/W07C_11_88.tif
# 9      images/swimming-pool/no/W07C_11_97.tif
# 10      images/swimming-pool/no/W07C_16_1.tif
# 11     images/swimming-pool/no/W07C_16_10.tif
# 12     images/swimming-pool/no/W07C_16_17.tif
# 13     images/swimming-pool/no/W07C_16_24.tif
# 14     images/swimming-pool/no/W07C_16_25.tif
# 15     images/swimming-pool/no/W07C_16_27.tif
# 16     images/swimming-pool/no/W07C_16_29.tif
# 17     images/swimming-pool/no/W07C_16_35.tif
# 18     images/swimming-pool/no/W07C_16_36.tif
# 19     images/swimming-pool/no/W07C_16_38.tif
# 20     images/swimming-pool/no/W07C_16_39.tif
# 21     images/swimming-pool/no/W07C_16_40.tif
# 22     images/swimming-pool/no/W07C_16_45.tif
# 23     images/swimming-pool/no/W07C_16_46.tif
# Name: key, dtype: object

# %%
service_request_files = files_df[
    files_df["key"].str.contains(
        r"(^|/)(sr|sr_hex|sr_hex_truncated)",
        case=False,
        regex=True
    )
]

service_request_files
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17352\290442126.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   files_df["key"].str.contains(
# Empty DataFrame
# Columns: [key, size_bytes, last_modified, file_type]
# Index: []

# %%
print(f"Total S3 objects discovered: {len(files_df):,}")
# Out:
# Total S3 objects discovered: 1,000

# %%
geojson_files = files_df[
    files_df["key"].str.contains(
        "city-hex",
        case=False,
        na=False
    )
]

geojson_files
# Out:
#                               key  size_bytes             last_modified  \
# 0     city-hex-polygons-7.geojson      276231 2021-05-14 09:52:18+00:00
# 1  city-hex-polygons-8-10.geojson   108254980 2021-05-14 09:44:09+00:00
# 2     city-hex-polygons-8.geojson     1966685 2021-05-14 13:10:00+00:00
#
#   file_type
# 0   geojson
# 1   geojson
# 2   geojson

# %%
required_sources = [
    "sr.csv.gz",
    "sr_hex.csv.gz",
    "sr_hex_truncated.csv",
    "city-hex-polygons-8.geojson",
    "city-hex-polygons-8-10.geojson",
]

source_check = []

for key in required_sources:
    try:
        response = s3.head_object(
            Bucket=BUCKET,
            Key=key
        )

        source_check.append({
            "key": key,
            "exists": True,
            "size_bytes": response["ContentLength"],
            "last_modified": response["LastModified"],
        })

    except s3.exceptions.ClientError as exc:
        source_check.append({
            "key": key,
            "exists": False,
            "size_bytes": None,
            "last_modified": None,
            "error": exc.response["Error"]["Code"],
        })

source_check_df = pd.DataFrame(source_check)

source_check_df
# Out:
#                               key  exists  size_bytes  \
# 0                       sr.csv.gz    True    37183035
# 1                   sr_hex.csv.gz    True    36657416
# 2            sr_hex_truncated.csv    True    63403673
# 3     city-hex-polygons-8.geojson    True     1966685
# 4  city-hex-polygons-8-10.geojson    True   108254980
#
#               last_modified
# 0 2022-06-21 20:13:07+00:00
# 1 2022-06-21 20:13:19+00:00
# 2 2022-06-21 20:13:32+00:00
# 3 2021-05-14 13:10:00+00:00
# 4 2021-05-14 09:44:09+00:00

# %% [markdown]
# one we have pictur of our sources in the s3 bucket as specified

# %%
required_sources = [
    "city-hex-polygons-8-10.geojson",
    "city-hex-polygons-8.geojson",
    "sr.csv.gz",
    "sr_hex.csv.gz",
    "sr_hex_truncated.csv",
]

source_inventory = files_df[
    files_df["key"].isin(required_sources)
].copy()

source_inventory
# Out:
#                               key  size_bytes             last_modified  \
# 1  city-hex-polygons-8-10.geojson   108254980 2021-05-14 09:44:09+00:00
# 2     city-hex-polygons-8.geojson     1966685 2021-05-14 13:10:00+00:00
#
#   file_type
# 1   geojson
# 2   geojson

# %% [markdown]
# get all the object in the storage

# %%
required_sources = [
    "city-hex-polygons-8-10.geojson",
    "city-hex-polygons-8.geojson",
    "sr.csv.gz",
    "sr_hex.csv.gz",
    "sr_hex_truncated.csv",
]

source_inventory = []

for key in required_sources:
    response = s3.head_object(
        Bucket=BUCKET,
        Key=key
    )

    source_inventory.append({
        "key": key,
        "size_bytes": response["ContentLength"],
        "last_modified": response["LastModified"],
    })

source_inventory_df = pd.DataFrame(source_inventory)

source_inventory_df
# Out:
#                               key  size_bytes             last_modified
# 0  city-hex-polygons-8-10.geojson   108254980 2021-05-14 09:44:09+00:00
# 1     city-hex-polygons-8.geojson     1966685 2021-05-14 13:10:00+00:00
# 2                       sr.csv.gz    37183035 2022-06-21 20:13:07+00:00
# 3                   sr_hex.csv.gz    36657416 2022-06-21 20:13:19+00:00
# 4            sr_hex_truncated.csv    63403673 2022-06-21 20:13:32+00:00

# %%
# %pip install s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2026.7.0-py3-none-any.whl (32 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0
#   Downloading aiohttp-3.14.3-cp310-cp310-win_amd64.whl (480 kB)
# Collecting fsspec<2026.7.1,>=2026.7.0
#   Downloading fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Collecting aiobotocore<4.0.0,>=2.19.0
#   Downloading aiobotocore-3.9.0-py3-none-any.whl (100 kB)
# Collecting aioitertools<1.0.0,>=0.5.1
#   Downloading aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Collecting wrapt<3.0.0,>=1.10.10
#   Downloading wrapt-2.3.0-cp310-cp310-win_amd64.whl (80 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (4.16.0)
# Collecting multidict<7.0.0,>=6.0.0
#   Downloading multidict-6.7.1-cp310-cp310-win_amd64.whl (46 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.1.0)
# Collecting botocore<1.43.57,>=1.43.3
#   Downloading botocore-1.43.56-py3-none-any.whl (15.4 MB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.9.0.post0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp310-cp310-win_amd64.whl (43 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.5.2-cp310-cp310-win_amd64.whl (42 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.24.5-cp310-cp310-win_amd64.whl (97 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting async-timeout<6.0,>=4.0
#   Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from botocore<1.43.57,>=1.43.3->aiobotocore<4.0.0,>=2.19.0->s3fs) (2.7.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<4.0.0,>=2.19.0->s3fs) (1.17.0)
# Collecting idna>=2.0
#   Downloading idna-3.19-py3-none-any.whl (68 kB)
# Installing collected packages: propcache, multidict, idna, frozenlist, yarl, attrs, async-timeout, aiosignal, aiohappyeyeballs, wrapt, botocore, aioitertools, aiohttp, fsspec, aiobotocore, s3fs
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.43.77
#     Uninstalling botocore-1.43.77:
#       Successfully uninstalled botocore-1.43.77
# Successfully installed aiobotocore-3.9.0 aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aioitertools-0.13.0 aiosignal-1.4.0 async-timeout-5.0.1 attrs-26.1.0 botocore-1.43.56 frozenlist-1.8.0 fsspec-2026.7.0 idna-3.19 multidict-6.7.1 propcache-0.5.2 s3fs-2026.7.0 wrapt-2.3.0 yarl-1.24.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.43.77 requires botocore<1.44.0,>=1.43.77, but you have botocore 1.43.56 which is incompatible.

# %%
import pandas as pd

sr = pd.read_csv(
    f"s3://{BUCKET}/sr.csv.gz",
    compression="gzip"
)

print(f"Rows: {len(sr):,}")
print(f"Columns: {len(sr.columns):,}")
# Out:
# Rows: 941,634
# Columns: 16

# %%
sr.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'notification_number',
#  'reference_number',
#  'creation_timestamp',
#  'completion_timestamp',
#  'directorate',
#  'department',
#  'branch',
#  'section',
#  'code_group',
#  'code',
#  'cause_code_group',
#  'cause_code',
#  'official_suburb',
#  'latitude',
#  'longitude']

# %%
sr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941634 entries, 0 to 941633
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            941634 non-null  int64
#  1   notification_number   941634 non-null  int64
#  2   reference_number      592920 non-null  float64
#  3   creation_timestamp    941634 non-null  object
#  4   completion_timestamp  929442 non-null  object
#  5   directorate           932199 non-null  object
#  6   department            932180 non-null  object
#  7   branch                913233 non-null  object
#  8   section               848509 non-null  object
#  9   code_group            941634 non-null  object
#  10  code                  941634 non-null  object
#  11  cause_code_group      131117 non-null  object
#  12  cause_code            129669 non-null  object
#  13  official_suburb       729221 non-null  object
#  14  latitude              729270 non-null  float64
#  15  longitude             729270 non-null  float64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 114.9+ MB

# %%
sr.head()
# Out:
#    Unnamed: 0  notification_number  reference_number  \
# 0           0            400583534      9.109492e+09
# 1           1            400555043      9.108995e+09
# 2           2            400589145      9.109614e+09
# 3           3            400538915      9.108601e+09
# 4           4            400568554               NaN
#
#           creation_timestamp       completion_timestamp     directorate  \
# 0  2020-10-07 06:55:18+02:00  2020-10-08 15:36:35+02:00  URBAN MOBILITY
# 1  2020-07-09 16:08:13+02:00  2020-07-14 14:27:01+02:00  URBAN MOBILITY
# 2  2020-10-27 10:21:59+02:00  2020-10-28 17:48:15+02:00  URBAN MOBILITY
# 3  2020-03-19 06:36:06+02:00  2021-03-29 20:34:19+02:00  URBAN MOBILITY
# 4  2020-08-25 09:48:42+02:00  2020-08-31 08:41:13+02:00  URBAN MOBILITY
#
#                         department            branch  \
# 0  Roads Infrastructure Management  RIM Area Central
# 1  Roads Infrastructure Management     RIM Area East
# 2  Roads Infrastructure Management     RIM Area East
# 3  Roads Infrastructure Management    RIM Area North
# 4  Roads Infrastructure Management    RIM Area South
#
#                     section                    code_group  \
# 0      District: Blaauwberg  TD Customer complaint groups
# 1  District : Somerset West  TD Customer complaint groups
# 2  District : Somerset West  TD Customer complaint groups
# 3      District : Bellville  TD Customer complaint groups
# 4        District : Athlone  TD Customer complaint groups
#
#                                      code cause_code_group         cause_code  \
# 0  Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)      Wear and tear
# 1                Manhole Cover/Gully Grid       Road (RCL)          Vandalism
# 2                Manhole Cover/Gully Grid       Road (RCL)          Vandalism
# 3              Paint Markings Lines&Signs    Road Markings      Wear and tear
# 4  Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)  Surfacing failure
#
#     official_suburb   latitude  longitude
# 0  MONTAGUE GARDENS -33.872839  18.522488
# 1     SOMERSET WEST -34.078916  18.848940
# 2            STRAND -34.102242  18.821116
# 3        RAVENSMEAD -33.920019  18.607209
# 4         CLAREMONT -33.987400  18.453760

# %%
sr[["latitude", "longitude"]].isna().sum()
# Out:
# latitude     212364
# longitude    212364
# dtype: int64

# %%
coordinate_nulls = sr[["latitude", "longitude"]].isna().sum()

coordinate_nulls
# Out:
# latitude     212364
# longitude    212364
# dtype: int64

# %%
print("Total records:", len(sr))
print("Records with coordinates:", sr[["latitude", "longitude"]].notna().all(axis=1).sum())
print("Records missing coordinates:", sr[["latitude", "longitude"]].isna().any(axis=1).sum())
print("Coordinate completeness:", f"{sr[['latitude', 'longitude']].notna().all(axis=1).mean():.2%}")
# Out:
# Total records: 941634
# Records with coordinates: 729270
# Records missing coordinates: 212364
# Coordinate completeness: 77.45%

# %% [markdown]
# Load sr_hex.csv.gz

# %%
sr_hex =pd.read_csv(f"s3://{BUCKET}/sr_hex.csv.gz", compression="gzip")

# %%
print("Rows:", len(sr_hex))
print("Columns:", len(sr_hex.columns))
# Out:
# Rows: 941634
# Columns: 16

# %%
sr_hex.columns.tolist()
# Out:
# ['notification_number',
#  'reference_number',
#  'creation_timestamp',
#  'completion_timestamp',
#  'directorate',
#  'department',
#  'branch',
#  'section',
#  'code_group',
#  'code',
#  'cause_code_group',
#  'cause_code',
#  'official_suburb',
#  'latitude',
#  'longitude',
#  'h3_level8_index']

# %%
sr_hex.head(10)
# Out:
#    notification_number  reference_number         creation_timestamp  \
# 0            400583534      9.109492e+09  2020-10-07 06:55:18+02:00
# 1            400555043      9.108995e+09  2020-07-09 16:08:13+02:00
# 2            400589145      9.109614e+09  2020-10-27 10:21:59+02:00
# 3            400538915      9.108601e+09  2020-03-19 06:36:06+02:00
# 4            400568554               NaN  2020-08-25 09:48:42+02:00
# 5            400556029      9.109003e+09  2020-07-11 10:34:37+02:00
# 6            400588369               NaN  2020-10-23 10:33:48+02:00
# 7            400549080               NaN  2020-06-17 15:46:11+02:00
# 8            400599701      9.109845e+09  2020-12-04 08:30:50+02:00
# 9            400569986               NaN  2020-08-28 13:37:53+02:00
#
#         completion_timestamp     directorate                       department  \
# 0  2020-10-08 15:36:35+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 1  2020-07-14 14:27:01+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 2  2020-10-28 17:48:15+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 3  2021-03-29 20:34:19+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 4  2020-08-31 08:41:13+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 5  2020-07-21 12:35:53+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 6  2020-10-26 14:16:49+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 7  2020-11-24 14:26:09+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 8  2020-12-14 12:53:52+02:00  URBAN MOBILITY  Roads Infrastructure Management
# 9  2020-08-28 16:17:35+02:00  URBAN MOBILITY  Roads Infrastructure Management
#
#              branch                   section                    code_group  \
# 0  RIM Area Central      District: Blaauwberg  TD Customer complaint groups
# 1     RIM Area East  District : Somerset West  TD Customer complaint groups
# 2     RIM Area East  District : Somerset West  TD Customer complaint groups
# 3    RIM Area North      District : Bellville  TD Customer complaint groups
# 4    RIM Area South        District : Athlone  TD Customer complaint groups
# 5     RIM Area East  District : Somerset West  TD Customer complaint groups
# 6    RIM Area North      District : Bellville  TD Customer complaint groups
# 7    RIM Area North      District : Bellville  TD Customer complaint groups
# 8  RIM Area Central       District: Cape Town  TD Customer complaint groups
# 9    RIM Area North   District : Kraaifontein  TD Customer complaint groups
#
#                                      code cause_code_group         cause_code  \
# 0  Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)      Wear and tear
# 1                Manhole Cover/Gully Grid       Road (RCL)          Vandalism
# 2                Manhole Cover/Gully Grid       Road (RCL)          Vandalism
# 3              Paint Markings Lines&Signs    Road Markings      Wear and tear
# 4  Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)  Surfacing failure
# 5  Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)       Base failure
# 6  Pothole&Defect Road Foot Bic Way/Kerbs              NaN                NaN
# 7  Pothole&Defect Road Foot Bic Way/Kerbs              NaN                NaN
# 8  Block Pipe/Chan/Canal/Drain/Gully/Manh              NaN                NaN
# 9  Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)  Surfacing failure
#
#          official_suburb   latitude  longitude  h3_level8_index
# 0       MONTAGUE GARDENS -33.872839  18.522488  88ad360225fffff
# 1          SOMERSET WEST -34.078916  18.848940  88ad36d5e1fffff
# 2                 STRAND -34.102242  18.821116  88ad36d437fffff
# 3             RAVENSMEAD -33.920019  18.607209  88ad361133fffff
# 4              CLAREMONT -33.987400  18.453760  88ad361709fffff
# 5                 STRAND -34.119520  18.829917  88ad36d43dfffff
# 6              GLENHAVEN -33.917996  18.658031  88ad361a19fffff
# 7             RAVENSMEAD -33.922154  18.596821  88ad3611edfffff
# 8  CAPE TOWN CITY CENTRE -33.925721  18.421675  88ad361519fffff
# 9            DURBANVILLE -33.835098  18.652708  88ad3618e5fffff

# %%
coordinate_nulls = sr_hex[["latitude", "longitude"]].isna().sum()

# %%
coordinate_nulls
# Out:
# latitude     212364
# longitude    212364
# dtype: int64

# %% [markdown]
# Compare row counts

# %%
set(sr_hex.columns) - set(sr.columns)
# Out:
# {'h3_level8_index'}

# %%
print("sr rows:", len(sr))
print("sr_hex rows:", len(sr_hex))
# Out:
# sr rows: 941634
# sr_hex rows: 941634

# %%
sr_hex["h3_level8_index"].value_counts(dropna=False).head()
# Out:
# h3_level8_index
# 0                  212364
# 88ad3612a9fffff      3815
# 88ad361009fffff      3464
# 88ad368985fffff      3393
# 88ad361519fffff      2797
# Name: count, dtype: int64

# %%
print(
    "H3 index 0:",
    (sr_hex["h3_level8_index"] == 0).sum()
)
# Out:
# H3 index 0: 0

# %%
print(
    "H3 index 0:",
    (sr_hex["h3_level8_index"] == "0").sum()
)
# Out:
# H3 index 0: 212364

# %%
print("Total records:", len(sr_hex))
print("H3 index 0:", (sr_hex["h3_level8_index"] == "0").sum())
print("Valid H3 index:", (sr_hex["h3_level8_index"] != "0").sum())
# Out:
# Total records: 941634
# H3 index 0: 212364
# Valid H3 index: 729270

# %% [markdown]
# GeoJSON reference file.

# %%
# %pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.4-py3-none-any.whl (343 kB)
# Collecting pyproj>=3.5.0
#   Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl (6.3 MB)
# Requirement already satisfied: numpy>=1.24 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from geopandas) (2.2.6)
# Collecting shapely>=2.0.0
#   Downloading shapely-2.1.2-cp310-cp310-win_amd64.whl (1.7 MB)
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.13.0-cp310-cp310-win_amd64.whl (23.9 MB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from geopandas) (26.3)
# Requirement already satisfied: pandas>=2.0.0 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from pandas>=2.0.0->geopandas) (2026.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from pandas>=2.0.0->geopandas) (2026.3.post1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.7.22)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\pythonproject\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.1.4 pyogrio-0.13.0 pyproj-3.7.1 shapely-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

hex8 = gpd.read_file(
    f"s3://{BUCKET}/city-hex-polygons-8.geojson"
)

print("Rows:", len(hex8))
print("Columns:", len(hex8.columns))
# Out:
# Rows: 3832
# Columns: 4

# %%
hex8.columns.tolist()
# Out:
# ['index', 'centroid_lat', 'centroid_lon', 'geometry']

# %%
hex8.head()
# Out:
#              index  centroid_lat  centroid_lon  \
# 0  88ad361801fffff    -33.859427     18.677843
# 1  88ad361803fffff    -33.855696     18.668766
# 2  88ad361805fffff    -33.855263     18.685959
# 3  88ad361807fffff    -33.851532     18.676881
# 4  88ad361809fffff    -33.867322     18.678806
#
#                                             geometry
# 0  POLYGON ((18.68119 -33.8633, 18.68357 -33.8592...
# 1  POLYGON ((18.67211 -33.85957, 18.6745 -33.8555...
# 2  POLYGON ((18.68931 -33.85914, 18.69169 -33.855...
# 3  POLYGON ((18.68023 -33.85541, 18.68261 -33.851...
# 4  POLYGON ((18.68215 -33.8712, 18.68454 -33.8671...

# %%
print("Hexagons:", len(hex8))
print("Unique H3 indexes:", hex8["index"].nunique())
print("Missing H3 indexes:", hex8["index"].isna().sum())
print("Missing geometry:", hex8["geometry"].isna().sum())
# Out:
# Hexagons: 3832
# Unique H3 indexes: 3832
# Missing H3 indexes: 0
# Missing geometry: 0

# %%
print("CRS:", hex8.crs)
print("Geometry types:")
print(hex8.geometry.geom_type.value_counts())
# Out:
# CRS: EPSG:4326
# Geometry types:
# Polygon    3832
# Name: count, dtype: int64

# %% [markdown]
# Notes
# Hexagons:              3,832
# Unique H3 indexes:     3,832
# Missing H3 indexes:    0
# Missing geometry:      0
# CRS:                   EPSG:4326
# Geometry type:         Polygon

# %% [markdown]
# we need tocheck if H3 resolution has json data lets checkit

# %%
response = s3.get_object(
    Bucket=BUCKET,
    Key="city-hex-polygons-8-10.geojson",
    Range="bytes=0-5000"
)

sample = response["Body"].read().decode("utf-8")

print(sample[:5000])
# Out:
# {
# "type": "FeatureCollection",
# "crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },
# "features": [
# { "type": "Feature", "properties": { "index": "88ad361801fffff", "centroid_lat": -33.859427322761434, "centroid_lon": 18.677843311941835, "resolution": 8 }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 18.6811898997334, -33.863302790817968 ], [ 18.683574296194426, -33.85928287732969 ], [ 18.680227609989728, -33.85540739558428 ], [ 18.674496767706248, -33.855551865779326 ], [ 18.672112346191998, -33.859571723609463 ], [ 18.675458791982372, -33.863447166906802 ], [ 18.6811898997334, -33.863302790817968 ] ] ] } },
# { "type": "Feature", "properties": { "index": "88ad361803fffff", "centroid_lat": -33.855695953283139, "centroid_lon": 18.668766173796456, "resolution": 8 }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 18.672112346191998, -33.859571723609463 ], [ 18.674496767706248, -33.855551865779326 ], [ 18.671150496788311, -33.851676081758441 ], [ 18.665420044866909, -33.851820194073497 ], [ 18.663035598432934, -33.855839996203308 ], [ 18.666381628808026, -33.859715741722489 ], [ 18.672112346191998, -33.859571723609463 ] ] ] } },
# { "type": "Feature", "properties": { "index": "88ad361805fffff", "centroid_lat": -33.855262542646564, "centroid_lon": 18.685958700425058, "resolution": 8 }, "geometry": { "type": "Polygon", "coordinates": [ [ [ 18.689305528598972, -33.859138049118094 ], [ 18.691689809315491, -33.855117645115939 ], [ 18.688342882830206, -33.851242124966504 ], [ 18.682611915876898, -33.851387047227377 ], [ 18.680227609989728, -33.85540739558428 ], [ 18.683574296194426, -33.85928287732969 ], [ 18.689305528598972, -33.859138049118094 ] ] ] } },
