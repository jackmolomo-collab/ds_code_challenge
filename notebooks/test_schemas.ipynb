# %%
docker exec ds_code_challenge-dagster-1 python -c "import polars as pl; df=pl.read_json('/opt/dagster/output/h3_resolution_8.json'); print(df.schema)"

# %% [markdown]
# Schema({'h3_index': String, 'centroid_lat': Float64, 'centroid_lon': Float64, 'resolution': Int64, 'geometry': Struct({'type': String, 'coordinates': List(List(List(Float64)))})})
# PS C:\Projects\City of Cape Town\Project\ds_code_challenge>

# %% [markdown]
# docker exec ds_code_challenge-dagster-1 sh -c "tail -50 /opt/dagster/dagster_home/logs/event.log"

# %% [markdown]
# docker exec ds_code_challenge-dagster-1 dagster job list
