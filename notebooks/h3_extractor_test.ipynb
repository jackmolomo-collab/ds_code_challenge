# %%
import sys
sys.path.insert(0, "..")

from src.extraction.h3_extractor import H3Extractor

extractor = H3Extractor()

h3_features = extractor.extract_resolution_8(
    "city-hex-polygons-8-10.geojson"
)

print(f"H3 level 8 features: {len(h3_features):,}")
# Out:
# H3 level 8 features: 3,832

# %%
h3_features[0]
# Out:
# {'type': 'Feature',
#  'properties': {'index': '88ad361801fffff',
#   'centroid_lat': -33.859427322761434,
#   'centroid_lon': 18.677843311941835,
#   'resolution': 8},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[18.6811898997334, -33.86330279081797],
#     [18.683574296194426, -33.85928287732969],
#     [18.68022760998973, -33.85540739558428],
#     [18.67449676770625, -33.855551865779326],
#     [18.672112346191998, -33.85957172360946],
#     [18.675458791982372, -33.8634471669068],
#     [18.6811898997334, -33.86330279081797]]]}}

# %% [markdown]
# pola data frame reads
