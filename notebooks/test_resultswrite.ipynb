# %%
import sys
from outputs.result_writer import ResultWriter

sys.path.insert(0, "..")

# %%
from outputs.result_writer import ResultWriter

writer = ResultWriter()

output_file = writer.write_json(
    result,
    "validation_result.json"
)

print(output_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       1 from outputs.result_writer import ResultWriter
#       3 writer = ResultWriter()
#       5 output_file = writer.write_json(
# ----> 6     result,
#       7     "validation_result.json"
#       8 )
#      10 print(output_file)
#
# NameError: name 'result' is not defined

# %%
dir(writer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'output_dir',
#  'write_json']
